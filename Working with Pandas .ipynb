# %%
import pandas
df1=pandas.DataFrame([{"Name":"Saharsh","Name":"Vaishnavi"},{"Age":12,"Age":19}])
df1
# Out:
#     Age       Name
# 0   NaN  Vaishnavi
# 1  19.0        NaN

# %%
import urllib.request,json
response=urllib.request.urlopen("http://api.openweathermap.org/data/2.5/weather?lat=29.88930833333333&lon=77.95958833333334&appid=b6907d289e10d714a6e88b30761fae22")
json.loads(response.read())
print(json)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-350f7eca8aa1> in <module>()
#       1 import urllib.request,json
# ----> 2 response=urllib.request.urlopen("http://api.openweathermap.org/data/2.5/weather?lat=29.88930833333333&lon=77.95958833333334&appid=b6907d289e10d714a6e88b30761fae22")
#       3 json.loads(response.read())
#       4 print(json)
#
# c:\users\shurru\appdata\local\programs\python\python36-32\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# c:\users\shurru\appdata\local\programs\python\python36-32\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
# ...

# %%
import requests
r = requests.get('http://api.openweathermap.org/data/2.5/forecast?lat=29.88930833333333&lon=77.95958833333334&appid=2e4cece87a1d0ae4bec92a7be776258a&units=metric')
print (r.json())
# Out:
# {'cod': '200', 'message': 0.0086, 'cnt': 40, 'list': [{'dt': 1524085200, 'main': {'temp': 16.58, 'temp_min': 16.58, 'temp_max': 20.18, 'pressure': 971.17, 'sea_level': 1019.1, 'grnd_level': 971.17, 'humidity': 44, 'temp_kf': -3.6}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 44}, 'wind': {'speed': 2.57, 'deg': 326.501}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-04-18 21:00:00'}, {'dt': 1524096000, 'main': {'temp': 16.29, 'temp_min': 16.29, 'temp_max': 18.99, 'pressure': 970.63, 'sea_level': 1018.78, 'grnd_level': 970.63, 'humidity': 50, 'temp_kf': -2.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'clouds': {'all': 0}, 'wind': {'speed': 1.75, 'deg': 342.502}, 'sys': {'pod': 'n'}, 'dt_txt': '2018-04-19 00:00:00'}, {'dt': 1524106800, 'main': {'temp': 23.97, 'temp_min': 23.97, 'temp_max': 25.77, 'pressure': 972.1, 'sea_level': 1019.88, 'grnd_level': 972.1, 'humidity': 43, 'temp_kf': 
# ...

# %%
import cv2
cv2.imread("smallgray.png",1)
#print(cv2)
# Out:
# array([[[187, 187, 187],
#         [158, 158, 158],
#         [104, 104, 104],
#         [121, 121, 121],
#         [143, 143, 143]],
#
#        [[198, 198, 198],
#         [125, 125, 125],
#         [255, 255, 255],
#         [255, 255, 255],
#         [147, 147, 147]],
#
#        [[209, 209, 209],
#         [134, 134, 134],
#         [255, 255, 255],
#         [ 97,  97,  97],
#         [182, 182, 182]]], dtype=uint8)

# %%
import numpy

help(numpy.array)
# Out:
# Help on built-in function array in module numpy.core.multiarray:
#
# array(...)
#     array(object, dtype=None, copy=True, order='K', subok=False, ndmin=0)
#
#     Create an array.
#
#     Parameters
#     ----------
#     object : array_like
#         An array, any object exposing the array interface, an object whose
#         __array__ method returns an array, or any (nested) sequence.
#     dtype : data-type, optional
#         The desired data-type for the array.  If not given, then the type will
#         be determined as the minimum type required to hold the objects in the
#         sequence.  This argument can only be used to 'upcast' the array.  For
#         downcasting, use the .astype(t) method.
#     copy : bool, optional
#         If true (default), then the object is copied.  Otherwise, a copy will
#         only be made if __array__ returns a copy, if obj is a nested sequence,
#         or if a copy is needed to satisfy any of the other requirements
# ...

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Testing.ipynb']

# %%
import pandas
df1=pandas.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df1=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df1
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
import pandas
df1=pandas.read_json("http://dataservice.accuweather.com/currentconditions/v1/3008489?apikey=ukARpEXeA9PI9rz6XIlHIUwzmPY0lPEx&details=true")
df1
# Out:
#                                  ApparentTemperature  \
# 0  {'Metric': {'Value': 20.6, 'Unit': 'C', 'UnitT...
#
#                                              Ceiling  CloudCover  \
# 0  {'Metric': {'Value': 9144.0, 'Unit': 'm', 'Uni...          31
#
#                                             DewPoint   EpochTime  IsDayTime  \
# 0  {'Metric': {'Value': 5.6, 'Unit': 'C', 'UnitTy...  1524000900      False
#
#                                                 Link  \
# 0  http://www.accuweather.com/en/in/belada/300848...
#
#     LocalObservationDateTime  \
# 0  2018-04-18T03:05:00+05:30
#
#                                           MobileLink ObstructionsToVisibility  \
# 0  http://m.accuweather.com/en/in/belada/3008489/...
#
#                          ...                          \
# 0                        ...
#
#                                   TemperatureSummary UVIndex UVIndexText  \
# 0  {'Past6HourRange': {'Minimum': {'Metric': {'Va...       0         Low
#
# ...

# %%
from geopy import Nominatim
nom=Nominatim()
nomi=nom.geocode("Roorkee,Uttarakhand,India")
nomi.latitude
nomi.longitude
# Out:
# geopy.location.Location
